# %%
print("Welcome to the word guessing Game")
import random
words=["apple","tiger","water","house","plant"]
word=random.choice(words)
attempts=6
hidden=["_"]*len(word)
while "_" in hidden and attempts>0:
    print(hidden)
    guess=input("Enter a letter:").lower()
    if guess in word:
        for i in range(len(word)):
            if word[i]==guess:
                hidden[i]=guess
    else:
        attempts-=1
        print("wrong guess")
if attempts==0:
    print("Game over! The word was:",word)
else:
    print("you guessed the word:",word)
# Out:
# Welcome to the word guessing Game
# ['_', '_', '_', '_', '_']
# Enter a letter: a
# wrong guess
# ['_', '_', '_', '_', '_']
# Enter a letter: t
# ['t', '_', '_', '_', '_']
# Enter a letter: i
# ['t', 'i', '_', '_', '_']
# Enter a letter: r
# ['t', 'i', '_', '_', 'r']
# Enter a letter: s
# wrong guess
# ['t', 'i', '_', '_', 'r']
# Enter a letter: e
# ['t', 'i', '_', 'e', 'r']
# Enter a letter: g
# you guessed the word: tiger
